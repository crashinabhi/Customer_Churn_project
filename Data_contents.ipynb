# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import OneHotEncoder
import pandas as pd
import tensorflow as tf

# Import our input dataset
train_df = pd.read_csv('Train Dataset.csv')
train_df.head()
# Out:
#                                     Customer ID  Is_Churn
# 0  ugx0CjOMzazClkFzU2xasmDZaoIqOUAZPsH1q0teWCg=         1
# 1  f/NmvEzHfhINFEYZTR05prUdr+E+3+oewvweYz9cCQE=         1
# 2  zLo9f73nGGT1p21ltZC3ChiRnAVvgibMyazbCxvWPcg=         1
# 3  8iF/+8HY8lJKFrTc7iR9ZYGCG2Ecrogbc2Vy5YhsfhQ=         1
# 4  K6fja4+jmoZ5xG6BypqX80Uw/XKpMgrEMdG2edFOxnA=         1

# %%
# Import our input dataset
members_details_df = pd.read_csv('Member Details.csv')
members_details_df.head()
# Out:
#                                     Customer ID  City  Age  Gender  \
# 0  Rb9UwLQTrxzBVwCB6+bCcSQWZ9JiNLC9dXtM1oEsZA8=     1    0     NaN
# 1  +tJonkh+O1CA796Fm5X60UMOtB6POHAwPjbTRVl/EuU=     1    0     NaN
# 2  cV358ssn7a0f7jZOwGNWS07wCKVqxyiImJUX6xcIwKw=     1    0     NaN
# 3  9bzDeJP6sQodK73K5CBlJ6fgIQzPeLnRl0p5B77XP+g=     1    0     NaN
# 4  WFLY3s7z4EZsieHCt63XrsdtfTEmJ+2PnnKLH5GY4Tk=     6   32  female
#
#    Registered_Via  Registered on
# 0              11       20110911
# 1               7       20110914
# 2              11       20110915
# 3              11       20110915
# 4               9       20110915

# %%
# Import our input dataset
transactions_df = pd.read_csv('Transactions.csv')
transactions_df.head()
# Out:
#                                     Customer ID  Payment_Method_ID  \
# 0  ++6eU4LsQ3UQ20ILS7d99XK8WbiVgbyYL4FUgzZR134=                 32
# 1  ++lvGPJOinuin/8esghpnqdljm6NXS8m8Zwchc7gOeA=                 41
# 2  +/GXNtXWQVfKrEDqYAzcSw2xSPYMKWNj22m+5XkVQZc=                 36
# 3  +/w1UrZwyka4C9oNH3+Q8fUf3fD8R3EwWrx57ODIsqk=                 36
# 4  +00PGzKTYqtnb65mPKPyeHXcZEwqiEzktpQksaaSC3c=                 41
#
#    Payment_Plan_Days  Plan_List_Price  Actual_Amount_Paid  Is_Auto_Renew  \
# 0                 90              298                 298              0
# 1                 30              149                 149              1
# 2                 30              180                 180              1
# 3                 30              180                 180              1
# 4                 30               99                  99              1
#
#    Transaction_Date  Membership_Expire_Date  Cancelled
# 0          20170131                20170504          0
# ...

# %%
# Import our input dataset
user_logs_df = pd.read_csv('User Logs.csv')
user_logs_df.head()
# Out:
#                                     Customer ID      Date  0-25%  25-50%  \
# 0  u9E91QDTvHLq6NXjEaWv8u4QIqhrHk72kE+w31Gnhdg=  20170331      8       4
# 1  nTeWW/eOZA/UHKdD5L7DEqKKFTjaAj3ALLPoAWsU8n0=  20170330      2       2
# 2  2UqkWXwZbIjs03dHLU9KHJNNEvEkZVzm69f3jCS+uLI=  20170331     52       3
# 3  ycwLc+m2O0a85jSLALtr941AaZt9ai8Qwlg9n0Nql5U=  20170331    176       4
# 4  EGcbTofOSOkMmQyN1NMLxHEXJ1yV3t/JdhGwQ9wXjnI=  20170331      2       1
#
#    50-75%  75-98.5%  Above 98.5%  Unique_songs  Total_secs
# 0       0         1           21            18    6309.273
# 1       1         0            9            11    2390.699
# 2       5         3           84           110   23203.337
# 3       2         2           19           191    7100.454
# 4       0         1          112            93   28401.558

# %%
# Merge the two DataFrames together
train_new_df = train_df.merge(members_details_df,left_index=True,right_index=True)
train_new_df.head()
# Out:
#                                   Customer ID_x  Is_Churn  \
# 0  ugx0CjOMzazClkFzU2xasmDZaoIqOUAZPsH1q0teWCg=         1
# 1  f/NmvEzHfhINFEYZTR05prUdr+E+3+oewvweYz9cCQE=         1
# 2  zLo9f73nGGT1p21ltZC3ChiRnAVvgibMyazbCxvWPcg=         1
# 3  8iF/+8HY8lJKFrTc7iR9ZYGCG2Ecrogbc2Vy5YhsfhQ=         1
# 4  K6fja4+jmoZ5xG6BypqX80Uw/XKpMgrEMdG2edFOxnA=         1
#
#                                   Customer ID_y  City  Age  Gender  \
# 0  Rb9UwLQTrxzBVwCB6+bCcSQWZ9JiNLC9dXtM1oEsZA8=     1    0     NaN
# 1  +tJonkh+O1CA796Fm5X60UMOtB6POHAwPjbTRVl/EuU=     1    0     NaN
# 2  cV358ssn7a0f7jZOwGNWS07wCKVqxyiImJUX6xcIwKw=     1    0     NaN
# 3  9bzDeJP6sQodK73K5CBlJ6fgIQzPeLnRl0p5B77XP+g=     1    0     NaN
# 4  WFLY3s7z4EZsieHCt63XrsdtfTEmJ+2PnnKLH5GY4Tk=     6   32  female
#
#    Registered_Via  Registered on
# 0              11       20110911
# 1               7       20110914
# 2              11       20110915
# 3              11       20110915
# 4               9       20110915

# %%
result = pd.merge(train_df, members_details_df, on="Customer ID")
result.head()
# Out:
#                                     Customer ID  Is_Churn  City  Age Gender  \
# 0  1AzXWFlRO6EfMBzfBdk98sBVnjzY7U1G24mVFNdzGNQ=         1    14   29   male
# 1  w2O0vchmncaBEQLoC5Pn7qRoSPiJ6X2x5O+woVFDhnY=         1    13    0    NaN
# 2  nGmbdyGVU+LCI2SXyYosErJCCYp371hQNP91BpP2d2I=         1    13   38   male
# 3  SlkPQrh6oIqsdpW+Sl2adYlJNEwWSQsIYycM11dSUQg=         1    14   49   male
# 4  ePx+sYifOKWLbG1fC8Gy2rjlg92Z7+Blxj94zzyC2+g=         1    22   18   male
#
#    Registered_Via  Registered on
# 0               3       20140510
# 1               9       20140605
# 2               3       20140608
# 3               7       20140611
# 4               9       20140719

# %%
result = pd.merge(result, transactions_df, on="Customer ID")
result.head()
# Out:
#                                     Customer ID  Is_Churn  City  Age Gender  \
# 0  1AzXWFlRO6EfMBzfBdk98sBVnjzY7U1G24mVFNdzGNQ=         1    14   29   male
# 1  1AzXWFlRO6EfMBzfBdk98sBVnjzY7U1G24mVFNdzGNQ=         1    14   29   male
# 2  1AzXWFlRO6EfMBzfBdk98sBVnjzY7U1G24mVFNdzGNQ=         1    14   29   male
# 3  w2O0vchmncaBEQLoC5Pn7qRoSPiJ6X2x5O+woVFDhnY=         1    13    0    NaN
# 4  nGmbdyGVU+LCI2SXyYosErJCCYp371hQNP91BpP2d2I=         1    13   38   male
#
#    Registered_Via  Registered on  Payment_Method_ID  Payment_Plan_Days  \
# 0               3       20140510                 32                 90
# 1               3       20140510                 33                 30
# 2               3       20140510                 33                 30
# 3               9       20140605                 40                 30
# 4               3       20140608                 32                180
#
#    Plan_List_Price  Actual_Amount_Paid  Is_Auto_Renew  Transaction_Date  \
# ...

# %%
result = pd.merge(result, user_logs_df, on="Customer ID")
result.head()
# Out:
#                                     Customer ID  Is_Churn  City  Age Gender  \
# 0  1AzXWFlRO6EfMBzfBdk98sBVnjzY7U1G24mVFNdzGNQ=         1    14   29   male
# 1  1AzXWFlRO6EfMBzfBdk98sBVnjzY7U1G24mVFNdzGNQ=         1    14   29   male
# 2  1AzXWFlRO6EfMBzfBdk98sBVnjzY7U1G24mVFNdzGNQ=         1    14   29   male
# 3  nGmbdyGVU+LCI2SXyYosErJCCYp371hQNP91BpP2d2I=         1    13   38   male
# 4  nGmbdyGVU+LCI2SXyYosErJCCYp371hQNP91BpP2d2I=         1    13   38   male
#
#    Registered_Via  Registered on  Payment_Method_ID  Payment_Plan_Days  \
# 0               3       20140510                 32                 90
# 1               3       20140510                 33                 30
# 2               3       20140510                 33                 30
# 3               3       20140608                 32                180
# 4               3       20140608                 32                180
#
#    Plan_List_Price  ...  Membership_Expire_Date  Cancelled      Date  0-25%  \
# ...
